# %% [markdown]
# ![Q1 dsp hw5.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Q2HW5DSP.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Q3A HW5DSP.jpeg](data:image/jpeg;base64,...)

# %%
import numpy as np
import matplotlib.pylab as plt
import scipy.signal
X=[1,2,3,4,4,3,2,1]
Y=[4,3,2,1,1,2,3,4]
[w,h1]=scipy.signal.freqz(X)
[w,h2]=scipy.signal.freqz(Y)
plt.plot(w,10*np.log(abs(h1)))
plt.plot(w,10*np.log(abs(h2)))
print("h1 has more near to LPF charectristics")
# Out:
# h1 has more near to LPF charectristics
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %% [markdown]
# ![Q4 dsp hw5.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![q5 HW5 DSP.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![6a dsp hw5.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![6b dsp hw5.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Q7 dsp hw5.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![8a dsp hw5..jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Solution 8b**
# We can have multiple values of sampling interval $T$ can be given as \
# $T=\frac{I}{N}\frac{2\pi}{\Omega_0}$
# \
#  where $N,\Omega_0, k$ are known and $I \in Integers$.

# %%
#Question 9a
import scipy.signal as sp
from scipy.fft import fft, fftshift
import matplotlib.pyplot as plt
import numpy as np
m=64;k=64/2
n=np.arange(-k,k)
x= np.cos(0.2*np.pi*n) + np.sin(0.22*np.pi*n) + 0.0005*np.sin(0.6*np.pi*n)
w = sp.boxcar(m)
plt.plot(w)
plt.title("Rectangular window")
plt.ylabel("Amplitude")
plt.xlabel("Sample")
y=(w*x)
w1,h=sp.freqz(y)
plt.figure(2)
g=20*np.log(h)
plt.plot(w1,g)
plt.grid(True)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
#Question 9a HANN WINDOW
x= np.cos(0.2*np.pi*n) + np.sin(0.22*np.pi*n) + 0.0005*np.sin(0.6*np.pi*n)
w = sp.hann(m)
plt.figure(1)
plt.plot(w)
plt.title("Hann window")
y=(w*x)
w1,h=sp.freqz(y)
plt.figure(2)
g=20*np.log(h)
plt.plot(w1,g)
plt.grid(True)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
#Question9a HAMM WINDOW
w = get_window('hamming', m)
plt.figure(1)
plt.plot(t, w)
plt.xlabel("(time) sample #")
plt.ylabel("amplitude")
plt.title("hamming window")
plt.xlim(0, m-1)
plt.ylim(-0.025, 1.025)
y=(w*x)
w1,h=sp.freqz(y)
plt.figure(2)
g=20*np.log(h)
plt.plot(w1,g)
plt.grid(True)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
#Q9b m=128
import scipy.signal as sp
from scipy.fft import fft, fftshift
import matplotlib.pyplot as plt
import numpy as np
m=128
k=128/2
n=np.arange(-k,k)
x= np.cos(0.2*np.pi*n) + np.sin(0.22*np.pi*n) + 0.0005*np.sin(0.6*np.pi*n)
w = sp.boxcar(m)
plt.figure(1)
plt.plot(w)
plt.title("Rectangular window")
plt.ylabel("Amplitude")
plt.xlabel("Sample")
y=(w*x)
w1,h=sp.freqz(y)
plt.figure(2)
g=20*np.log(h)
plt.plot(w1,g)
plt.grid(True)
#Hann Window m=128
w = sp.hann(m)
plt.figure(3)
plt.plot(w)
plt.title("Hann window")
plt.ylabel("Amplitude")
plt.xlabel("Sample")
y=(w*x)
w1,h=sp.freqz(y)
plt.figure(4)
g=20*np.log(h)
plt.plot(w1,g)
plt.grid(True)
#HAMM WIN m=128
w = get_window('hamming', m)
plt.figure(5)
plt.plot(t, w)
plt.xlabel("(time) sample #")
plt.ylabel("amplitude")
plt.title("hamming window")
plt.xlim(0, m-1)
plt.ylim(-0.025, 1.025)
y=(w*x)
w1,h=sp.freqz(y)
plt.figure(6)
g=20*np.log(h)
plt.plot(w1,g)
plt.grid(True)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
#9b m=256 rect
import scipy.signal as sp
from scipy.fft import fft, fftshift
import matplotlib.pyplot as plt
import numpy as np
m=256
k=m/2
n=np.arange(-k,k)
x= np.cos(0.2*np.pi*n) + np.sin(0.22*np.pi*n) + 0.0005*np.sin(0.6*np.pi*n)
w = sp.boxcar(m)
plt.plot(w)
plt.title("Rectangular window")
plt.ylabel("Amplitude")
plt.xlabel("Sample")
y=(w*x)
w1,h=sp.freqz(y)
plt.figure(2)
g=20*np.log(h)
plt.plot(w1,g)
plt.grid(True)
#9b hann 256
w = sp.hann(m)
plt.figure(3)
plt.plot(w)
plt.title("Hann window")
plt.ylabel("Amplitude")
plt.xlabel("Sample")
y=(w*x)
w1,h=sp.freqz(y)
plt.figure(4)
g=20*np.log(h)
plt.plot(w1,g)
plt.grid(True)
#9b hAMM 256
w = get_window('hamming', m)
plt.figure(5)
plt.plot(w)
plt.xlabel("(time) sample #")
plt.ylabel("amplitude")
plt.title("hamming window")
plt.xlim(0, m-1)
plt.ylim(-0.025, 1.025)
y=(w*x)
w1,h=sp.freqz(y)
plt.figure(6)
g=20*np.log(h)
plt.plot(w1,g)
plt.grid(True)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
#9b m=1024 rect
import scipy.signal as sp
from scipy.fft import fft, fftshift
import matplotlib.pyplot as plt
import numpy as np
m=1024
k=m/2
n=np.arange(-k,k)
x= np.cos(0.2*np.pi*n) + np.sin(0.22*np.pi*n) + 0.0005*np.sin(0.6*np.pi*n)
w = sp.boxcar(m)
plt.plot(w)
plt.title("Rectangular window")
plt.ylabel("Amplitude")
plt.xlabel("Sample")
y=(w*x)
w1,h=sp.freqz(y)
plt.figure(2)
g=20*np.log(h)
plt.plot(w1,g)
plt.grid(True)
#9b hann 1024
w = sp.hann(m)
plt.figure(3)
plt.plot(w)
plt.title("Hann window")
plt.ylabel("Amplitude")
plt.xlabel("Sample")
y=(w*x)
w1,h=sp.freqz(y)
plt.figure(4)
g=20*np.log(h)
plt.plot(w1,g)
plt.grid(True)
#9b hAMM 1024
w = get_window('hamming', m)
plt.figure(5)
plt.plot(w)
plt.xlabel("(time) sample #")
plt.ylabel("amplitude")
plt.title("hamming window")
plt.xlim(0, m-1)
plt.ylim(-0.025, 1.025)
y=(w*x)
w1,h=sp.freqz(y)
plt.figure(6)
g=20*np.log(h)
plt.plot(w1,g)
plt.grid(True)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
#9b m=4096 rect
import scipy.signal as sp
from scipy.fft import fft, fftshift
import matplotlib.pyplot as plt
import numpy as np
m=1024
k=m/2
n=np.arange(-k,k)
x= np.cos(0.2*np.pi*n) + np.sin(0.22*np.pi*n) + 0.0005*np.sin(0.6*np.pi*n)
w = sp.boxcar(m)
plt.plot(w)
plt.title("Rectangular window")
plt.ylabel("Amplitude")
plt.xlabel("Sample")
y=(w*x)
w1,h=sp.freqz(y)
plt.figure(2)
g=20*np.log(h)
plt.plot(w1,g)
plt.grid(True)
#9b hann 4096
w = sp.hann(m)
plt.figure(3)
plt.plot(w)
plt.title("Hann window")
plt.ylabel("Amplitude")
plt.xlabel("Sample")
y=(w*x)
w1,h=sp.freqz(y)
plt.figure(4)
g=20*np.log(h)
plt.plot(w1,g)
plt.grid(True)
#9b hAMM 4096
w = get_window('hamming', m)
plt.figure(5)
plt.plot(w)
plt.xlabel("(time) sample #")
plt.ylabel("amplitude")
plt.title("hamming window")
plt.xlim(0, m-1)
plt.ylim(-0.025, 1.025)
y=(w*x)
w1,h=sp.freqz(y)
plt.figure(6)
g=20*np.log(h)
plt.plot(w1,g)
plt.grid(True)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
